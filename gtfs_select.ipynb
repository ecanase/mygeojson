# %% [markdown]
# <a href="https://colab.research.google.com/github/ecanase/mygeojson/blob/main/gtfs_select.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalamos gtfs_kit
# Gtfs_kit ofrece utlidades para inspeccionar los archivos gtfs,
# además nos servirá para saber si el gtfs es correcto.

# %%
# !pip install gtfs_kit
# !pip install geojsonio
#!wget "https://openmobilitydata.org/p/transports-metropolitans-de-barcelona-tmb/995/latest/download"

# %%
l

# %% [markdown]
# # Visualizar los Pandas Dataframes interactivamente
#
# Colab incluye una extensión que permite visualizar los dataframes de pandas de manera interactiva, filtrando, ordenando y explorando los registros se pueda activar con
#
# ```python
# %load_ext google.colab.data_table
# ```
# y desactivar ejecutando
# ```python
# %unload_ext google.colab.data_table
# ```

# %%
# %load_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
gfts_filenames =['https://openmobilitydata.org/p/transports-metropolitans-de-barcelona-tmb/995/latest/download',
                 'https://openmobilitydata.org/p/amb-mobilitat/994/latest/download',
                 'https://openmobilitydata.org/p/tram-trambaix/996/latest/download',
                 'https://openmobilitydata.org/p/tram-trambesos/997/latest/download',
                 'https://www.fgc.cat/google/google_transit.zip', #ferrocarils.
                 'https://openmobilitydata.org/p/renfe/1016/latest/download', # Rodalies Tota España
                 'https://openmobilitydata.org/p/renfe/1018/latest/download'  # Mitja distancia TOTA españa
                 ]


import gtfs_kit as gk

feed = gk.read_feed(gfts_filenames[3],dist_units='km')

# %%
feed.agency

# %%
feed.routes

# %%
feed.trips
# Out:
#      route_id         service_id  ... shape_id wheelchair_accessible
# 0           4            FEINERS  ...    T4ANA                     1
# 1           4            FEINERS  ...    T4ANA                     1
# 2           4            FEINERS  ...    T4ANA                     1
# 3           4            FEINERS  ...    T4ANA                     1
# 4           4            FEINERS  ...    T4ANA                     1
# ...       ...                ...  ...      ...                   ...
# 6402        6  DIVENDRES_FINS_1H  ...    T6TOR                     1
# 6403        6  DIVENDRES_FINS_1H  ...    T6TOR                     1
# 6404        6  DIVENDRES_FINS_1H  ...    T6TOR                     1
# 6405        6  DIVENDRES_FINS_1H  ...    T6TOR                     1
# 6406        6  DIVENDRES_FINS_1H  ...    T6TOR                     1
#
# [6407 rows x 7 columns]

# %%
geojson = feed.shapes_to_geojson()

print(geojson)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'shape_id': 'T4ANA'}, 'geometry': {'type': 'LineString', 'coordinates': [[2.191928, 41.387606], [2.191456, 41.387965], [2.191262, 41.388109], [2.1892810000000003, 41.389609], [2.188524, 41.390173], [2.18705, 41.391301], [2.1869959999999997, 41.391362], [2.1869560000000003, 41.391418], [2.186932, 41.391477], [2.186909, 41.391587], [2.186902, 41.391678999999996], [2.1869009999999998, 41.391769000000004], [2.186903, 41.391890999999994], [2.186903, 41.392771999999994], [2.186907, 41.393282], [2.186914, 41.394071000000004], [2.186913, 41.394646], [2.1869110000000003, 41.394785999999996], [2.186903, 41.394906], [2.1868790000000002, 41.395132000000004], [2.186866, 41.395329], [2.186867, 41.395641], [2.18687, 41.396478], [2.186873, 41.396769], [2.18688, 41.397535999999995], [2.186884, 41.398235], [2.1868849999999997, 41.39852], [2.18689, 41.398714], [2.186891, 41.399178000000006], [2.186891, 41.399543], [2.186892, 
# ...
